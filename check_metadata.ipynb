# %%
import pandas as pd 

report4_metadata = pd.read_csv("./metadata/REPORT4.csv", index_col = [0])

newdata = pd.read_csv("./metadata/Vi_new_validation_CRC_data_11012025.csv")

[item for item in newdata.SampleID_BS.unique() if item not in report4_metadata.SampleID.unique()]
# Out:
# ['K0AAAH47',
#  'K0AAAH61',
#  'K0AAAH99',
#  'K0AAAI41',
#  'K0AAAI77',
#  'K0AAAI88',
#  'K0AAAI95',
#  'K0AAAJ01',
#  'K0AAAJ04',
#  'K0AAAJ12',
#  'K0AAAK45',
#  'K0AAAK49',
#  'K0AAAK63',
#  'K0AAAK73',
#  'K0AAAK79',
#  'K0AAAK90',
#  'K0AAAU57',
#  'K0AAAU61',
#  'K0AAAU63',
#  'K0AAAU65',
#  'K0AAAU72',
#  'K0AAAV87',
#  'K0AAAW01',
#  'K0AAAW02',
#  'K0AAAW04',
#  'K0AAAW06',
#  'K0AAAW08',
#  'K0AAAW30',
#  'K0AAAW37',
#  'K0AAAW47',
#  'K0AAAW83',
#  'K0AAAW86',
#  'K0AAAW89',
#  'K0AAAW97',
#  'K0AAAW99',
#  'K0AAAX02',
#  'K0AAAX07',
#  'K0CAAH88',
#  'K0CAAI16',
#  'K0CAAI17',
#  'K0CAAI19',
#  'K0CAAI24',
#  'K0CAAI25',
#  'K0CAAI28',
#  'K0CAAI47',
#  'K0CAAI63',
#  'K0CAAI65',
#  'K0CAAI70',
#  'K0CAAI75',
#  'K0CAAI76',
#  'K0CAAI82',
#  'K0DAAF19',
#  'K0DAAF20',
#  'K0DAAF28',
#  'K0GAAK39',
#  'K0GAAK42',
#  'K0GAAK52',
#  'K0GAAK53',
#  'K2AAAA88',
#  'K2AAAA97',
#  'K2AAAB39',
#  'K2AAAB41',
#  'K2AAAB42',
#  'K2AAAB45',
#  'K2AAAB47',
#  'K2AAAB52',
# ...
